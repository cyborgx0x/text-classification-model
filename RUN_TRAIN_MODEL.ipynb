# %%
# !git clone https://github.com/cyborgx0x/model_trainer model_trainer
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu117
# !pip install -r requirements.txt
from google.colab import output
output.clear()

# %%
from huggingface_hub import notebook_login
notebook_login()

# %%
from model_trainer.model import Core, Config
from model_trainer.model.dataset import get_dataset

# %%
data_file = "/content/Dataset.xlsx"

# %%
runner = Core(
    dataset = get_dataset(
        excel_file=data_file
    )   
)

# %%
runner._run()
